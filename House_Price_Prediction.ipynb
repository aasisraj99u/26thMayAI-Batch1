# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('housing.csv')

# %%
df.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df['Price'].nunique()
# Out:
# 5000

# %%
df['Avg. Area Income'].plot.hist(bins=30)

# %%
df['Avg. Area House Age'].plot.hist(bins=20)

# %%
for i in df.columns[:-1]:
    df[i].hist(bins=20)
    plt.title(i)
    plt.show()

# %%
for i in df.columns[:-2]:
    df.plot.scatter(i,'Price')
    plt.title(i)

# %%
import seaborn as sns

# %%
sns.pairplot(df,kind='reg')

# %%
features = df.drop(['Avg. Area Number of Bedrooms','Price','Address'],axis=1)

# %%
features.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Area Population
# 0     23086.800503
# 1     40173.072174
# 2     36882.159400
# 3     34310.242831
# 4     26354.109472
# 5     26748.428425
# 6     60828.249085
# 7     36516.358972
# 8     29387.396003
# ...

# %%
label = df['Price']

# %%
label.head(10)
# Out:
# 0    1.059034e+06
# 1    1.505891e+06
# 2    1.058988e+06
# 3    1.260617e+06
# 4    6.309435e+05
# 5    1.068138e+06
# 6    1.502056e+06
# 7    1.573937e+06
# 8    7.988695e+05
# 9    1.545155e+06
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(features,label,test_size=0.25,random_state=56)

# %%
train_x.head(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1076      75302.082580             6.759325                   7.822847
# 3748      55795.380729             6.663035                   6.982778
# 3437      57535.887652             4.090968                   7.572639
# 426       69807.723356             7.424253                   7.257604
# 1985      70021.161534             7.143144                   7.748338
# 64        59539.948450             6.018590                   7.007676
# 2934      76674.522103             7.152425                   9.293513
# 2983      79095.279230             6.666809                   6.738534
# 2748      61355.945983             7.513298                   6.388363
# 4649      57782.057028             4.671946                   9.067015
#
#       Area Population
# 1076     42382.751532
# 3748     26448.033973
# 3437     31668.246117
# 426      51453.265163
# 1985     44935.884831
# 64       58600.827150
# 2934     43156.086784
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([2.15633749e+01, 1.65170724e+05, 1.22471469e+05, 1.51379829e+01])

# %%
pd.DataFrame(model.coef_,columns=['Coef'],index= features.columns)
# Out:
#                                     Coef
# Avg. Area Income               21.563375
# Avg. Area House Age        165170.723546
# Avg. Area Number of Rooms  122471.468767
# Area Population                15.137983

# %% [markdown]
# ### Evaluation

# %%
print('%.1f'%(model.score(test_x,test_y)*100))
# Out:
# 92.3

# %%
ypred = model.predict(test_x)

# %%
ypred
# Out:
# array([1339482.09709917, 1182271.84376454, 1553762.3728033 , ...,
#        1640822.42180921, 1470919.89943892, 1134148.27520949])

# %%
test_y
# Out:
# 3296    1.563193e+06
# 4860    8.935415e+05
# 389     1.662039e+06
# 2873    9.987020e+05
# 1420    9.720796e+05
#             ...
# 982     1.559679e+06
# 2343    1.553854e+06
# 2990    1.553396e+06
# 1548    1.394424e+06
# 4352    1.308465e+06
# Name: Price, Length: 1250, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
mae(test_y,ypred)
# Out:
# 78979.76519934718

# %%
100*mae(test_y,ypred)/ypred[0]
# Out:
# 5.896291213625669

# %% [markdown]
# ### Deployment

# %%
final_model = model

# %%
pd.to_pickle(final_model,'HousePricePredictor') # Saving the model

# %%
model = pd.read_pickle('HousePricePredictor')

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
cols = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address']

# %%
income = eval(input('Enter the Income: '))
house_age = eval(input('Enter the house age: '))
rooms = eval(input('Enter the no of rooms: '))
population =  eval(input('Enter the population: '))

query = pd.DataFrame({
    'Avg. Area Income':[income],
    'Avg. Area House Age':[house_age],
    'Avg. Area Number of Rooms':[rooms],
    'Area Populaion': [population]
})
# Out:
# Enter the Income: 50000
# Enter the house age: 15
# Enter the no of rooms: 5
# Enter the population: 1000000

# %%
query
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             50000                   15                          5
#
#    Area Populaion
# 0         1000000

# %%
price= model.predict(query)[0]
price
# Out:
# 16669869.466200642

# %%
print('Price of the house is: {}'.format(round(price,2)))
# Out:
# Price of the house is: 16669869.47
